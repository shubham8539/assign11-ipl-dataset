# %%
import numpy as np
import pandas as pd

# %%
delivery=pd.read_csv("deliveries.csv")
delivery
# Out:
#         match_id  inning                 batting_team  \
# 0              1       1          Sunrisers Hyderabad
# 1              1       1          Sunrisers Hyderabad
# 2              1       1          Sunrisers Hyderabad
# 3              1       1          Sunrisers Hyderabad
# 4              1       1          Sunrisers Hyderabad
# 5              1       1          Sunrisers Hyderabad
# 6              1       1          Sunrisers Hyderabad
# 7              1       1          Sunrisers Hyderabad
# 8              1       1          Sunrisers Hyderabad
# 9              1       1          Sunrisers Hyderabad
# 10             1       1          Sunrisers Hyderabad
# 11             1       1          Sunrisers Hyderabad
# 12             1       1          Sunrisers Hyderabad
# 13             1       1          Sunrisers Hyderabad
# 14             1       1          Sunrisers Hyderabad
# 15             1       1          Sunrisers Hyderabad
# ...

# %%
top_bat=delivery.groupby('batsman')['batsman_runs'].sum().sort_values(ascending=False).head(10)
best_bat=top_bat.index.tolist()
best_bat
# Out:
# ['SK Raina',
#  'V Kohli',
#  'RG Sharma',
#  'G Gambhir',
#  'DA Warner',
#  'RV Uthappa',
#  'CH Gayle',
#  'S Dhawan',
#  'MS Dhoni',
#  'AB de Villiers']

# %%
top_bowlers=delivery.dropna(subset=['player_dismissed']).copy()

l=list()
for i,row in top_bowlers.iterrows():
    if row['dismissal_kind']=='run out' or row['dismissal_kind']=='retired hurt' or row['dismissal_kind']=='obstructing the field':
        l.append(i)
for i in l:
    top_bowlers.drop(i,inplace=True)
top_bowlers=top_bowlers.groupby('bowler')['player_dismissed'].count().sort_values(ascending=False).head(10)
best_bowl=top_bowlers.index.tolist()
best_bowl
# Out:
# ['SL Malinga',
#  'A Mishra',
#  'Harbhajan Singh',
#  'PP Chawla',
#  'DJ Bravo',
#  'B Kumar',
#  'A Nehra',
#  'R Vinay Kumar',
#  'Z Khan',
#  'R Ashwin']

# %%
new=delivery[delivery['batsman'].isin(best_bat)]
new
# Out:
#         match_id  inning                 batting_team  \
# 0              1       1          Sunrisers Hyderabad
# 1              1       1          Sunrisers Hyderabad
# 2              1       1          Sunrisers Hyderabad
# 3              1       1          Sunrisers Hyderabad
# 4              1       1          Sunrisers Hyderabad
# 5              1       1          Sunrisers Hyderabad
# 6              1       1          Sunrisers Hyderabad
# 7              1       1          Sunrisers Hyderabad
# 8              1       1          Sunrisers Hyderabad
# 9              1       1          Sunrisers Hyderabad
# 10             1       1          Sunrisers Hyderabad
# 11             1       1          Sunrisers Hyderabad
# 14             1       1          Sunrisers Hyderabad
# 18             1       1          Sunrisers Hyderabad
# 22             1       1          Sunrisers Hyderabad
# 23             1       1          Sunrisers Hyderabad
# ...

# %%
best_best=new[new['bowler'].isin(best_bowl)]
best_best
# Out:
#         match_id  inning                 batting_team           bowling_team  \
# 125            1       2  Royal Challengers Bangalore    Sunrisers Hyderabad
# 131            1       2  Royal Challengers Bangalore    Sunrisers Hyderabad
# 132            1       2  Royal Challengers Bangalore    Sunrisers Hyderabad
# 133            1       2  Royal Challengers Bangalore    Sunrisers Hyderabad
# 137            1       2  Royal Challengers Bangalore    Sunrisers Hyderabad
# 138            1       2  Royal Challengers Bangalore    Sunrisers Hyderabad
# 139            1       2  Royal Challengers Bangalore    Sunrisers Hyderabad
# 142            1       2  Royal Challengers Bangalore    Sunrisers Hyderabad
# 144            1       2  Royal Challengers Bangalore    Sunrisers Hyderabad
# 145            1       2  Royal Challengers Bangalore    Sunrisers Hyderabad
# 146            1       2  Royal Challengers Bangalore    Sunrisers Hyderabad
# ...

# %%
compare=best_best.pivot_table(index='batsman',columns='bowler',values='batsman_runs',aggfunc='sum')
compare
# Out:
# bowler          A Mishra  A Nehra  B Kumar  DJ Bravo  Harbhajan Singh  \
# batsman
# AB de Villiers       9.0     61.0     48.0      69.0             80.0
# CH Gayle            45.0     45.0    104.0      53.0             78.0
# DA Warner           37.0     25.0      2.0      44.0             97.0
# G Gambhir           54.0     27.0     84.0      32.0             84.0
# MS Dhoni            24.0     76.0     81.0      55.0             47.0
# RG Sharma           78.0     62.0     31.0      66.0              8.0
# RV Uthappa          84.0     55.0     65.0      32.0             75.0
# S Dhawan            16.0     42.0     14.0      48.0            103.0
# SK Raina            83.0     15.0     62.0      55.0            132.0
# V Kohli            149.0     60.0     53.0     130.0             78.0
#
# bowler          PP Chawla  R Ashwin  R Vinay Kumar  SL Malinga  Z Khan
# batsman
# AB de Villiers       43.0      42.0           16.0        76.0    28.0
# ...

# %%
import seaborn as sns
sns.heatmap(compare)
